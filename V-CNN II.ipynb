# %%
import sys
sys.path.append("D:/Notebooks/modules")
from utils import scantree
from utils_3d import show_slices_gif_tensor, show_slices_gif_paths, rotate_3d_tensor, plot_3d_volume_mayavi, TensorPathsDataset
from transforms import Rotate3d
from CTKidney_models import VCNNII

import random
import torch
from torch import nn
import torchsummary
import os
from collections import defaultdict
import re
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
# Out:
# d:\ProgramFiles\anaconda3\envs\pytorch_env\Lib\site-packages\onnxscript\converter.py:820: FutureWarning: 'onnxscript.values.Op.param_schemas' is deprecated in version 0.1 and will be removed in the future. Please use '.op_signature' instead.
#   param_schemas = callee.param_schemas()
# d:\ProgramFiles\anaconda3\envs\pytorch_env\Lib\site-packages\onnxscript\converter.py:820: FutureWarning: 'onnxscript.values.OnnxFunction.param_schemas' is deprecated in version 0.1 and will be removed in the future. Please use '.op_signature' instead.
#   param_schemas = callee.param_schemas()

# %%
config = {
    'input_shape': (30, 128, 128),
    'batch_size': 64,
    'device': torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
    'n_epochs': 200,
    'seed': 0
}

# %%
train_dataset = TensorPathsDataset(r'D:\Notebooks\Kidney CT\augmented_volumes\Rotate3d_AllAxes_-30to30_RandomFlip3d\Train', 20, 'train')
valid_dataset = TensorPathsDataset(r'D:\Notebooks\Kidney CT\augmented_volumes\Rotate3d_AllAxes_-30to30_RandomFlip3d\Valid', 20, 'valid')

print(len(train_dataset), len(valid_dataset))

train_loader = DataLoader(train_dataset, batch_size = config['batch_size'], shuffle= True)
valid_loader = DataLoader(valid_dataset, batch_size = config['batch_size'])

volumes, labels = next(iter(valid_loader))
print(volumes.shape, labels.shape)
print(volumes.min(), volumes.max(), labels)

show_slices_gif_tensor(volumes[0][0])
# plot_3d_volume_mayavi(volumes[0][0])
# Out:
# 152 21
# torch.Size([21, 20, 30, 128, 128]) torch.Size([21])
# tensor(0.) tensor(1.) tensor([0, 3, 3, 0, 0, 2, 0, 2, 1, 1, 0, 3, 1, 1, 2, 0, 0, 1, 3, 1, 3])

# %%
model = VCNNII(input_shape = config['input_shape'], n_outputs=4).to(config['device'])
torchsummary.summary(model, input_size = config['input_shape'])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 20, 128, 128]             620
#             Conv2d-2         [-1, 20, 128, 128]           5,420
#             Conv2d-3         [-1, 20, 128, 128]          15,020
#               ReLU-4         [-1, 60, 128, 128]               0
#            Dropout-5         [-1, 60, 128, 128]               0
#    InceptionBlock1-6         [-1, 60, 128, 128]               0
#             Conv2d-7         [-1, 30, 128, 128]           1,830
#             Conv2d-8         [-1, 30, 128, 128]          16,230
#               ReLU-9         [-1, 60, 128, 128]               0
#           Dropout-10         [-1, 60, 128, 128]               0
#   InceptionBlock2-11         [-1, 60, 128, 128]               0
#            Conv2d-12         [-1, 30, 128, 128]          16,230
#              ReLU-13         [-1, 30, 128, 128]               0
#           Dropout-14         [-1, 30, 128, 128]               0
#           Flatten-15               [-1, 491520]               0
#            Linear-16                 [-1, 2048]   1,006,635,008
#              ReLU-17                 [-1, 2048]               0
#            Linear-18                    [-1, 4]           8,196
# ================================================================
# Total params: 1,006,698,554
# Trainable params: 1,006,698,554
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 1.88
# Forward/backward pass size (MB): 75.03
# Params size (MB): 3840.25
# Estimated Total Size (MB): 3917.16
# ----------------------------------------------------------------

# %%
optimizer = torch.optim.SGD(model.parameters(), lr = 0.001, weight_decay= 0.001, momentum= 0.9)
loss_fn = nn.CrossEntropyLoss()

def get_accuracy(logits, targets):
    preds = torch.argmax(logits, dim = 1)
    return torch.sum(preds == targets).item() / len(preds)

# %%
train_losses = []
valid_losses = []

best_acc = 0
best_loss = 100

for epoch in range(config['n_epochs']):
    train_loss = 0
    valid_loss = 0
    
    train_acc = 0
    valid_acc = 0
    
    model.train()
    
    for volumes, labels in train_loader:
        volumes, labels = volumes.to(config['device']), labels.to(config['device'])
        
        logits = model(volumes)
        loss = loss_fn(logits, labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        train_loss += loss.detach().cpu().item()
        train_acc += get_accuracy(logits, labels)
        
    model.eval()
    
    with torch.inference_mode():
        for batch, labels in valid_loader:
            batch, labels = batch.to(config['device']), labels.to(config['device'])
            logits_list = []

            for volumes in batch:
                logits = model.forward_multi_view(volumes)
                logits_list.append(logits.squeeze())

            logits_list = torch.stack(logits_list)
            loss = loss_fn(logits_list, labels)
            valid_loss += loss.detach().cpu().item()
            valid_acc += get_accuracy(logits_list, labels)

    train_loss /= len(train_loader)
    valid_loss /= len(valid_loader)
    train_acc /= len(train_loader)
    valid_acc /= len(valid_loader)

    train_losses.append(train_loss)
    valid_losses.append(valid_loss)

    if epoch % 1 == 0:
        print(f"Epoch: {epoch+1} | Train Loss: {train_loss:.4f} | Valid Loss: {valid_loss:.4f} | Train Acc: {train_acc:.4f} | Valid Acc: {valid_acc:.4f}")

    # Save the model with highest accuracy
    if epoch > 10 and ((valid_acc > best_acc) or (valid_acc == best_acc and valid_loss < best_loss)):
        best_acc, best_loss = valid_acc, valid_loss
        torch.save(model.state_dict(), "V-CNN II.pt")
        print("Checkpoint was saved!")

print(f"Best validation accuracy: {best_acc:.4f}")
# Out:
# Epoch: 1 | Train Loss: 1.3876 | Valid Loss: 1.3892 | Train Acc: 0.2830 | Valid Acc: 0.1429
# Epoch: 2 | Train Loss: 1.3783 | Valid Loss: 1.3881 | Train Acc: 0.2812 | Valid Acc: 0.3333
# Epoch: 3 | Train Loss: 1.3682 | Valid Loss: 1.3885 | Train Acc: 0.3611 | Valid Acc: 0.3333
# Epoch: 4 | Train Loss: 1.3621 | Valid Loss: 1.3909 | Train Acc: 0.3750 | Valid Acc: 0.3333
# Epoch: 5 | Train Loss: 1.3473 | Valid Loss: 1.3966 | Train Acc: 0.3576 | Valid Acc: 0.3333
# Epoch: 6 | Train Loss: 1.3256 | Valid Loss: 1.4072 | Train Acc: 0.3924 | Valid Acc: 0.3333
# Epoch: 7 | Train Loss: 1.3072 | Valid Loss: 1.4234 | Train Acc: 0.3837 | Valid Acc: 0.3333
# Epoch: 8 | Train Loss: 1.3236 | Valid Loss: 1.4490 | Train Acc: 0.3750 | Valid Acc: 0.3333
# Epoch: 9 | Train Loss: 1.2846 | Valid Loss: 1.4694 | Train Acc: 0.4184 | Valid Acc: 0.3333
# Epoch: 10 | Train Loss: 1.2835 | Valid Loss: 1.4811 | Train Acc: 0.3924 | Valid Acc: 0.3333
# Epoch: 11 | Train Loss: 1.3352 | Valid Loss: 1.4858 | Train Acc: 0.3924 | Valid Acc: 0.3333
# Epoch: 12 | Train Loss: 1.2735 | Valid Loss: 1.4712 | Train Acc: 0.4097 | Valid Acc: 0.3333
# Checkpoint was saved!
# Epoch: 13 | Train Loss: 1.3245 | Valid Loss: 1.4641 | Train Acc: 0.3490 | Valid Acc: 0.3333
# Checkpoint was saved!
# Epoch: 14 | Train Loss: 1.3274 | Valid Loss: 1.4521 | Train Acc: 0.3576 | Valid Acc: 0.3333
# Checkpoint was saved!
# Epoch: 15 | Train Loss: 1.3202 | Valid Loss: 1.4355 | Train Acc: 0.3490 | Valid Acc: 0.3333
# Checkpoint was saved!
# Epoch: 16 | Train Loss: 1.2981 | Valid Loss: 1.4212 | Train Acc: 0.3750 | Valid Acc: 0.3333
# Checkpoint was saved!
# Epoch: 17 | Train Loss: 1.2983 | Valid Loss: 1.4133 | Train Acc: 0.3663 | Valid Acc: 0.3333
# Checkpoint was saved!
# Epoch: 18 | Train Loss: 1.2910 | Valid Loss: 1.4085 | Train Acc: 0.3663 | Valid Acc: 0.3333
# Checkpoint was saved!
# Epoch: 19 | Train Loss: 1.2929 | Valid Loss: 1.4033 | Train Acc: 0.3663 | Valid Acc: 0.3333
# Checkpoint was saved!
# Epoch: 20 | Train Loss: 1.2905 | Valid Loss: 1.4034 | Train Acc: 0.3576 | Valid Acc: 0.3333
# Epoch: 21 | Train Loss: 1.2562 | Valid Loss: 1.4098 | Train Acc: 0.4010 | Valid Acc: 0.3333
# Epoch: 22 | Train Loss: 1.2963 | Valid Loss: 1.4208 | Train Acc: 0.3490 | Valid Acc: 0.3333
# Epoch: 23 | Train Loss: 1.2667 | Valid Loss: 1.4226 | Train Acc: 0.3837 | Valid Acc: 0.3333
# Epoch: 24 | Train Loss: 1.2640 | Valid Loss: 1.4060 | Train Acc: 0.3767 | Valid Acc: 0.3333
# Epoch: 25 | Train Loss: 1.2492 | Valid Loss: 1.3755 | Train Acc: 0.3889 | Valid Acc: 0.3333
# Checkpoint was saved!
# Epoch: 26 | Train Loss: 1.2199 | Valid Loss: 1.3431 | Train Acc: 0.4097 | Valid Acc: 0.4762
# Checkpoint was saved!
# Epoch: 27 | Train Loss: 1.2144 | Valid Loss: 1.3188 | Train Acc: 0.4444 | Valid Acc: 0.5238
# Checkpoint was saved!
# Epoch: 28 | Train Loss: 1.1880 | Valid Loss: 1.3041 | Train Acc: 0.4826 | Valid Acc: 0.5238
# Checkpoint was saved!
# Epoch: 29 | Train Loss: 1.1822 | Valid Loss: 1.2924 | Train Acc: 0.4948 | Valid Acc: 0.5238
# Checkpoint was saved!
# Epoch: 30 | Train Loss: 1.1008 | Valid Loss: 1.2815 | Train Acc: 0.5017 | Valid Acc: 0.5238
# Checkpoint was saved!
# Epoch: 31 | Train Loss: 1.1019 | Valid Loss: 1.2893 | Train Acc: 0.4931 | Valid Acc: 0.5238
# Epoch: 32 | Train Loss: 1.0501 | Valid Loss: 1.2707 | Train Acc: 0.5191 | Valid Acc: 0.5238
# Checkpoint was saved!
# Epoch: 33 | Train Loss: 1.0179 | Valid Loss: 1.2684 | Train Acc: 0.5608 | Valid Acc: 0.5714
# Checkpoint was saved!
# Epoch: 34 | Train Loss: 1.0087 | Valid Loss: 1.3043 | Train Acc: 0.4688 | Valid Acc: 0.5714
# Epoch: 35 | Train Loss: 1.0096 | Valid Loss: 1.3190 | Train Acc: 0.5417 | Valid Acc: 0.5714
# Epoch: 36 | Train Loss: 0.9765 | Valid Loss: 1.3514 | Train Acc: 0.5486 | Valid Acc: 0.4286
# Epoch: 37 | Train Loss: 0.9737 | Valid Loss: 1.3739 | Train Acc: 0.5035 | Valid Acc: 0.4762
# Epoch: 38 | Train Loss: 1.0107 | Valid Loss: 1.3956 | Train Acc: 0.4965 | Valid Acc: 0.6190
# Checkpoint was saved!
# Epoch: 39 | Train Loss: 0.9577 | Valid Loss: 1.3225 | Train Acc: 0.5677 | Valid Acc: 0.6190
# Checkpoint was saved!
# Epoch: 40 | Train Loss: 0.9433 | Valid Loss: 1.3288 | Train Acc: 0.5677 | Valid Acc: 0.5238
# Epoch: 41 | Train Loss: 0.9975 | Valid Loss: 1.3335 | Train Acc: 0.5677 | Valid Acc: 0.5238
# Epoch: 42 | Train Loss: 0.9946 | Valid Loss: 1.3518 | Train Acc: 0.5365 | Valid Acc: 0.5714
# Epoch: 43 | Train Loss: 1.0004 | Valid Loss: 1.3490 | Train Acc: 0.5503 | Valid Acc: 0.4762
# Epoch: 44 | Train Loss: 0.9872 | Valid Loss: 1.3342 | Train Acc: 0.5295 | Valid Acc: 0.3810
# Epoch: 45 | Train Loss: 0.9386 | Valid Loss: 1.3074 | Train Acc: 0.5816 | Valid Acc: 0.4286
# Epoch: 46 | Train Loss: 0.9778 | Valid Loss: 1.2989 | Train Acc: 0.5660 | Valid Acc: 0.4286
# Epoch: 47 | Train Loss: 0.9506 | Valid Loss: 1.2931 | Train Acc: 0.5347 | Valid Acc: 0.5714
# Epoch: 48 | Train Loss: 0.9600 | Valid Loss: 1.3013 | Train Acc: 0.5573 | Valid Acc: 0.5714
# Epoch: 49 | Train Loss: 0.9617 | Valid Loss: 1.3174 | Train Acc: 0.4809 | Valid Acc: 0.4762
# Epoch: 50 | Train Loss: 0.9251 | Valid Loss: 1.3098 | Train Acc: 0.5642 | Valid Acc: 0.4286
# Epoch: 51 | Train Loss: 0.9322 | Valid Loss: 1.3054 | Train Acc: 0.5660 | Valid Acc: 0.4286
# Epoch: 52 | Train Loss: 0.8868 | Valid Loss: 1.2990 | Train Acc: 0.5486 | Valid Acc: 0.3810
# Epoch: 53 | Train Loss: 0.9759 | Valid Loss: 1.2977 | Train Acc: 0.5556 | Valid Acc: 0.4762
# Epoch: 54 | Train Loss: 0.9186 | Valid Loss: 1.2835 | Train Acc: 0.5642 | Valid Acc: 0.4286
# Epoch: 55 | Train Loss: 0.9329 | Valid Loss: 1.2586 | Train Acc: 0.5122 | Valid Acc: 0.5238
# Epoch: 56 | Train Loss: 0.9675 | Valid Loss: 1.2310 | Train Acc: 0.5625 | Valid Acc: 0.5238
# Epoch: 57 | Train Loss: 1.0157 | Valid Loss: 1.2051 | Train Acc: 0.5903 | Valid Acc: 0.5238
# Epoch: 58 | Train Loss: 0.9240 | Valid Loss: 1.1873 | Train Acc: 0.6111 | Valid Acc: 0.4762
# Epoch: 59 | Train Loss: 0.9243 | Valid Loss: 1.2168 | Train Acc: 0.5625 | Valid Acc: 0.4286
# Epoch: 60 | Train Loss: 0.9263 | Valid Loss: 1.2281 | Train Acc: 0.5382 | Valid Acc: 0.4762
# Epoch: 61 | Train Loss: 0.9581 | Valid Loss: 1.2265 | Train Acc: 0.5382 | Valid Acc: 0.5714
# Epoch: 62 | Train Loss: 0.9394 | Valid Loss: 1.2281 | Train Acc: 0.5990 | Valid Acc: 0.5714
# Epoch: 63 | Train Loss: 0.8775 | Valid Loss: 1.2178 | Train Acc: 0.6163 | Valid Acc: 0.4762
# Epoch: 64 | Train Loss: 0.9729 | Valid Loss: 1.2086 | Train Acc: 0.5556 | Valid Acc: 0.6190
# Checkpoint was saved!
# Epoch: 65 | Train Loss: 0.9090 | Valid Loss: 1.1682 | Train Acc: 0.5972 | Valid Acc: 0.5714
# Epoch: 66 | Train Loss: 0.9211 | Valid Loss: 1.1750 | Train Acc: 0.6042 | Valid Acc: 0.5238
# Epoch: 67 | Train Loss: 0.9258 | Valid Loss: 1.1720 | Train Acc: 0.5747 | Valid Acc: 0.4286
# Epoch: 68 | Train Loss: 0.9018 | Valid Loss: 1.1815 | Train Acc: 0.5799 | Valid Acc: 0.4286
# Epoch: 69 | Train Loss: 0.9123 | Valid Loss: 1.1920 | Train Acc: 0.5764 | Valid Acc: 0.4762
# Epoch: 70 | Train Loss: 0.8967 | Valid Loss: 1.1860 | Train Acc: 0.5660 | Valid Acc: 0.6190
# Checkpoint was saved!
# Epoch: 71 | Train Loss: 0.8800 | Valid Loss: 1.1873 | Train Acc: 0.5677 | Valid Acc: 0.5714
# Epoch: 72 | Train Loss: 0.8967 | Valid Loss: 1.2170 | Train Acc: 0.5903 | Valid Acc: 0.4762
# Epoch: 73 | Train Loss: 0.9125 | Valid Loss: 1.2322 | Train Acc: 0.5521 | Valid Acc: 0.4762
# Epoch: 74 | Train Loss: 0.9044 | Valid Loss: 1.2086 | Train Acc: 0.6545 | Valid Acc: 0.4286
# Epoch: 75 | Train Loss: 0.8118 | Valid Loss: 1.2044 | Train Acc: 0.6684 | Valid Acc: 0.4286
# Epoch: 76 | Train Loss: 0.9077 | Valid Loss: 1.2251 | Train Acc: 0.5833 | Valid Acc: 0.4286
# Epoch: 77 | Train Loss: 0.9720 | Valid Loss: 1.2127 | Train Acc: 0.5278 | Valid Acc: 0.4286
# Epoch: 78 | Train Loss: 0.8622 | Valid Loss: 1.1775 | Train Acc: 0.6458 | Valid Acc: 0.6190
# Checkpoint was saved!
# Epoch: 79 | Train Loss: 0.9002 | Valid Loss: 1.1490 | Train Acc: 0.5694 | Valid Acc: 0.6190
# Checkpoint was saved!
# Epoch: 80 | Train Loss: 0.8372 | Valid Loss: 1.1515 | Train Acc: 0.6649 | Valid Acc: 0.5714
# Epoch: 81 | Train Loss: 0.8771 | Valid Loss: 1.1795 | Train Acc: 0.6076 | Valid Acc: 0.4762
# Epoch: 82 | Train Loss: 0.8539 | Valid Loss: 1.2181 | Train Acc: 0.5868 | Valid Acc: 0.4762
# Epoch: 83 | Train Loss: 0.8769 | Valid Loss: 1.2149 | Train Acc: 0.6146 | Valid Acc: 0.4762
# Epoch: 84 | Train Loss: 0.8609 | Valid Loss: 1.1889 | Train Acc: 0.6319 | Valid Acc: 0.4762
# Epoch: 85 | Train Loss: 0.9081 | Valid Loss: 1.1500 | Train Acc: 0.5694 | Valid Acc: 0.5238
# Epoch: 86 | Train Loss: 0.8752 | Valid Loss: 1.1489 | Train Acc: 0.6337 | Valid Acc: 0.5238
# Epoch: 87 | Train Loss: 0.8616 | Valid Loss: 1.1558 | Train Acc: 0.5955 | Valid Acc: 0.3810
# Epoch: 88 | Train Loss: 0.8382 | Valid Loss: 1.1723 | Train Acc: 0.6024 | Valid Acc: 0.4762
# Epoch: 89 | Train Loss: 0.8902 | Valid Loss: 1.1568 | Train Acc: 0.5573 | Valid Acc: 0.3810
# Epoch: 90 | Train Loss: 0.8783 | Valid Loss: 1.1326 | Train Acc: 0.5764 | Valid Acc: 0.3810
# Epoch: 91 | Train Loss: 0.8339 | Valid Loss: 1.1373 | Train Acc: 0.6007 | Valid Acc: 0.5238
# Epoch: 92 | Train Loss: 0.8064 | Valid Loss: 1.1586 | Train Acc: 0.6302 | Valid Acc: 0.4762
# Epoch: 93 | Train Loss: 0.8212 | Valid Loss: 1.2152 | Train Acc: 0.6285 | Valid Acc: 0.3810
# Epoch: 94 | Train Loss: 0.8159 | Valid Loss: 1.2040 | Train Acc: 0.6267 | Valid Acc: 0.3810
# Epoch: 95 | Train Loss: 0.8510 | Valid Loss: 1.1894 | Train Acc: 0.6285 | Valid Acc: 0.5238
# Epoch: 96 | Train Loss: 0.8340 | Valid Loss: 1.1950 | Train Acc: 0.6250 | Valid Acc: 0.5238
# Epoch: 97 | Train Loss: 0.9275 | Valid Loss: 1.1918 | Train Acc: 0.5642 | Valid Acc: 0.4762
# Epoch: 98 | Train Loss: 0.8569 | Valid Loss: 1.1701 | Train Acc: 0.5955 | Valid Acc: 0.3810
# Epoch: 99 | Train Loss: 0.8326 | Valid Loss: 1.1500 | Train Acc: 0.6406 | Valid Acc: 0.3810
# Epoch: 100 | Train Loss: 0.8581 | Valid Loss: 1.1556 | Train Acc: 0.5712 | Valid Acc: 0.4762
# Epoch: 101 | Train Loss: 0.8824 | Valid Loss: 1.1495 | Train Acc: 0.5590 | Valid Acc: 0.4762
# Epoch: 102 | Train Loss: 0.8911 | Valid Loss: 1.1608 | Train Acc: 0.5903 | Valid Acc: 0.4286
# Epoch: 103 | Train Loss: 0.8837 | Valid Loss: 1.1347 | Train Acc: 0.6094 | Valid Acc: 0.4286
# Epoch: 104 | Train Loss: 0.8437 | Valid Loss: 1.1034 | Train Acc: 0.6146 | Valid Acc: 0.5238
# Epoch: 105 | Train Loss: 0.8645 | Valid Loss: 1.1065 | Train Acc: 0.5191 | Valid Acc: 0.4762
# Epoch: 106 | Train Loss: 0.8948 | Valid Loss: 1.0916 | Train Acc: 0.6302 | Valid Acc: 0.6667
# Checkpoint was saved!
# Epoch: 107 | Train Loss: 0.9136 | Valid Loss: 1.0828 | Train Acc: 0.5677 | Valid Acc: 0.5238
# Epoch: 108 | Train Loss: 0.7942 | Valid Loss: 1.1677 | Train Acc: 0.6562 | Valid Acc: 0.4762
# Epoch: 109 | Train Loss: 0.8584 | Valid Loss: 1.1589 | Train Acc: 0.5747 | Valid Acc: 0.3810
# Epoch: 110 | Train Loss: 0.8495 | Valid Loss: 1.1614 | Train Acc: 0.6545 | Valid Acc: 0.5714
# Epoch: 111 | Train Loss: 0.8060 | Valid Loss: 1.1369 | Train Acc: 0.6910 | Valid Acc: 0.4286
# Epoch: 112 | Train Loss: 0.8876 | Valid Loss: 1.1589 | Train Acc: 0.5833 | Valid Acc: 0.4286
# Epoch: 113 | Train Loss: 0.8432 | Valid Loss: 1.1668 | Train Acc: 0.6250 | Valid Acc: 0.4762
# Epoch: 114 | Train Loss: 0.8306 | Valid Loss: 1.1671 | Train Acc: 0.6076 | Valid Acc: 0.3810
# Epoch: 115 | Train Loss: 0.7994 | Valid Loss: 1.2227 | Train Acc: 0.6146 | Valid Acc: 0.3810
# Epoch: 116 | Train Loss: 0.9770 | Valid Loss: 1.1851 | Train Acc: 0.5799 | Valid Acc: 0.3810
# Epoch: 117 | Train Loss: 0.8349 | Valid Loss: 1.1252 | Train Acc: 0.6059 | Valid Acc: 0.5714
# Epoch: 118 | Train Loss: 0.8389 | Valid Loss: 1.1110 | Train Acc: 0.6181 | Valid Acc: 0.5714
# Epoch: 119 | Train Loss: 0.8499 | Valid Loss: 1.1343 | Train Acc: 0.6128 | Valid Acc: 0.3810
# Epoch: 120 | Train Loss: 0.8100 | Valid Loss: 1.1402 | Train Acc: 0.6823 | Valid Acc: 0.4762
# Epoch: 121 | Train Loss: 0.7382 | Valid Loss: 1.1770 | Train Acc: 0.6719 | Valid Acc: 0.4762
# Epoch: 122 | Train Loss: 0.8369 | Valid Loss: 1.1687 | Train Acc: 0.6042 | Valid Acc: 0.4286
# Epoch: 123 | Train Loss: 0.8087 | Valid Loss: 1.1051 | Train Acc: 0.6181 | Valid Acc: 0.5714
# Epoch: 124 | Train Loss: 0.8173 | Valid Loss: 1.1009 | Train Acc: 0.5938 | Valid Acc: 0.5714
# Epoch: 125 | Train Loss: 0.8076 | Valid Loss: 1.1045 | Train Acc: 0.6302 | Valid Acc: 0.5714
# Epoch: 126 | Train Loss: 0.8194 | Valid Loss: 1.1159 | Train Acc: 0.5955 | Valid Acc: 0.5714
# Epoch: 127 | Train Loss: 0.8448 | Valid Loss: 1.1513 | Train Acc: 0.6597 | Valid Acc: 0.4762
# Epoch: 128 | Train Loss: 0.8514 | Valid Loss: 1.1574 | Train Acc: 0.6111 | Valid Acc: 0.4286
# Epoch: 129 | Train Loss: 0.8413 | Valid Loss: 1.1659 | Train Acc: 0.6510 | Valid Acc: 0.6667
# Epoch: 130 | Train Loss: 0.8763 | Valid Loss: 1.1636 | Train Acc: 0.6215 | Valid Acc: 0.4762
# Epoch: 131 | Train Loss: 0.8892 | Valid Loss: 1.1421 | Train Acc: 0.6267 | Valid Acc: 0.4286
# Epoch: 132 | Train Loss: 0.8320 | Valid Loss: 1.1145 | Train Acc: 0.6372 | Valid Acc: 0.4286
# Epoch: 133 | Train Loss: 0.8546 | Valid Loss: 1.0985 | Train Acc: 0.6319 | Valid Acc: 0.4762
# Epoch: 134 | Train Loss: 0.8120 | Valid Loss: 1.1396 | Train Acc: 0.6510 | Valid Acc: 0.5238
# Epoch: 135 | Train Loss: 0.9022 | Valid Loss: 1.1007 | Train Acc: 0.5451 | Valid Acc: 0.5238
# Epoch: 136 | Train Loss: 0.7991 | Valid Loss: 1.0982 | Train Acc: 0.6042 | Valid Acc: 0.5238
# Epoch: 137 | Train Loss: 0.8067 | Valid Loss: 1.1058 | Train Acc: 0.6424 | Valid Acc: 0.5238
# Epoch: 138 | Train Loss: 0.8045 | Valid Loss: 1.1504 | Train Acc: 0.6111 | Valid Acc: 0.4762
# Epoch: 139 | Train Loss: 0.8315 | Valid Loss: 1.2320 | Train Acc: 0.5833 | Valid Acc: 0.4286
# Epoch: 140 | Train Loss: 0.8135 | Valid Loss: 1.2271 | Train Acc: 0.6458 | Valid Acc: 0.4286
# Epoch: 141 | Train Loss: 0.7529 | Valid Loss: 1.1583 | Train Acc: 0.6806 | Valid Acc: 0.4762
# Epoch: 142 | Train Loss: 0.8480 | Valid Loss: 1.1600 | Train Acc: 0.5503 | Valid Acc: 0.4762
# Epoch: 143 | Train Loss: 0.8431 | Valid Loss: 1.2006 | Train Acc: 0.6007 | Valid Acc: 0.3810
# Epoch: 144 | Train Loss: 0.7903 | Valid Loss: 1.1956 | Train Acc: 0.6597 | Valid Acc: 0.4286
# Epoch: 145 | Train Loss: 0.7874 | Valid Loss: 1.1164 | Train Acc: 0.6458 | Valid Acc: 0.5238
# Epoch: 146 | Train Loss: 0.8311 | Valid Loss: 1.1112 | Train Acc: 0.6198 | Valid Acc: 0.5238
# Epoch: 147 | Train Loss: 0.8047 | Valid Loss: 1.1889 | Train Acc: 0.6389 | Valid Acc: 0.3810
# Epoch: 148 | Train Loss: 0.8334 | Valid Loss: 1.1257 | Train Acc: 0.6476 | Valid Acc: 0.4762
# Epoch: 149 | Train Loss: 0.7978 | Valid Loss: 1.1003 | Train Acc: 0.6667 | Valid Acc: 0.5714
# Epoch: 150 | Train Loss: 0.7846 | Valid Loss: 1.1949 | Train Acc: 0.6562 | Valid Acc: 0.4286
# Epoch: 151 | Train Loss: 0.9876 | Valid Loss: 1.2053 | Train Acc: 0.5174 | Valid Acc: 0.3810
# Epoch: 152 | Train Loss: 0.8250 | Valid Loss: 1.1287 | Train Acc: 0.6302 | Valid Acc: 0.6190
# Epoch: 153 | Train Loss: 0.8072 | Valid Loss: 1.1904 | Train Acc: 0.6337 | Valid Acc: 0.5714
# Epoch: 154 | Train Loss: 0.7990 | Valid Loss: 1.2553 | Train Acc: 0.5816 | Valid Acc: 0.4286
# Epoch: 155 | Train Loss: 0.8683 | Valid Loss: 1.2470 | Train Acc: 0.5903 | Valid Acc: 0.4762
# Epoch: 156 | Train Loss: 0.7856 | Valid Loss: 1.1868 | Train Acc: 0.6910 | Valid Acc: 0.4762
# Epoch: 157 | Train Loss: 0.7354 | Valid Loss: 1.1711 | Train Acc: 0.7049 | Valid Acc: 0.4762
# Epoch: 158 | Train Loss: 0.7841 | Valid Loss: 1.1882 | Train Acc: 0.6545 | Valid Acc: 0.5238
# Epoch: 159 | Train Loss: 0.7271 | Valid Loss: 1.1757 | Train Acc: 0.6615 | Valid Acc: 0.4762
# Epoch: 160 | Train Loss: 0.8139 | Valid Loss: 1.1525 | Train Acc: 0.6319 | Valid Acc: 0.4762
# Epoch: 161 | Train Loss: 0.7230 | Valid Loss: 1.1464 | Train Acc: 0.6962 | Valid Acc: 0.4286
# Epoch: 162 | Train Loss: 0.7669 | Valid Loss: 1.1503 | Train Acc: 0.6510 | Valid Acc: 0.5238
# Epoch: 163 | Train Loss: 0.7884 | Valid Loss: 1.1367 | Train Acc: 0.6337 | Valid Acc: 0.6190
# Epoch: 164 | Train Loss: 0.7318 | Valid Loss: 1.1767 | Train Acc: 0.6875 | Valid Acc: 0.4762
# Epoch: 165 | Train Loss: 0.7683 | Valid Loss: 1.2099 | Train Acc: 0.6476 | Valid Acc: 0.4762
# Epoch: 166 | Train Loss: 0.7909 | Valid Loss: 1.2101 | Train Acc: 0.6233 | Valid Acc: 0.5238
# Epoch: 167 | Train Loss: 0.7665 | Valid Loss: 1.2215 | Train Acc: 0.6597 | Valid Acc: 0.5238
# Epoch: 168 | Train Loss: 0.7506 | Valid Loss: 1.2157 | Train Acc: 0.7361 | Valid Acc: 0.4762
# Epoch: 169 | Train Loss: 0.8116 | Valid Loss: 1.2473 | Train Acc: 0.6354 | Valid Acc: 0.4286
# Epoch: 170 | Train Loss: 0.8011 | Valid Loss: 1.2861 | Train Acc: 0.6788 | Valid Acc: 0.4762
# Epoch: 171 | Train Loss: 0.7217 | Valid Loss: 1.2766 | Train Acc: 0.6649 | Valid Acc: 0.4286
# Epoch: 172 | Train Loss: 0.7844 | Valid Loss: 1.2674 | Train Acc: 0.6701 | Valid Acc: 0.3333
# Epoch: 173 | Train Loss: 0.7391 | Valid Loss: 1.2096 | Train Acc: 0.6719 | Valid Acc: 0.4762
# Epoch: 174 | Train Loss: 0.7178 | Valid Loss: 1.2942 | Train Acc: 0.6788 | Valid Acc: 0.5714
# Epoch: 175 | Train Loss: 0.8152 | Valid Loss: 1.3060 | Train Acc: 0.6545 | Valid Acc: 0.4286
# Epoch: 176 | Train Loss: 0.7786 | Valid Loss: 1.3026 | Train Acc: 0.6649 | Valid Acc: 0.4286
# Epoch: 177 | Train Loss: 0.7347 | Valid Loss: 1.2236 | Train Acc: 0.6962 | Valid Acc: 0.5714
# Epoch: 178 | Train Loss: 0.7779 | Valid Loss: 1.3177 | Train Acc: 0.6806 | Valid Acc: 0.5238
# Epoch: 179 | Train Loss: 0.7230 | Valid Loss: 1.3293 | Train Acc: 0.6997 | Valid Acc: 0.3333
# Epoch: 180 | Train Loss: 0.8386 | Valid Loss: 1.2851 | Train Acc: 0.5990 | Valid Acc: 0.3810
# Epoch: 181 | Train Loss: 0.7019 | Valid Loss: 1.3039 | Train Acc: 0.6997 | Valid Acc: 0.5714
# Epoch: 182 | Train Loss: 0.7761 | Valid Loss: 1.1870 | Train Acc: 0.6562 | Valid Acc: 0.4762
# Epoch: 183 | Train Loss: 0.7132 | Valid Loss: 1.2188 | Train Acc: 0.7448 | Valid Acc: 0.3810
# Epoch: 184 | Train Loss: 0.7372 | Valid Loss: 1.3006 | Train Acc: 0.6580 | Valid Acc: 0.4762
# Epoch: 185 | Train Loss: 0.6854 | Valid Loss: 1.1723 | Train Acc: 0.7396 | Valid Acc: 0.4286
# Epoch: 186 | Train Loss: 0.7058 | Valid Loss: 1.1189 | Train Acc: 0.6979 | Valid Acc: 0.4762
# Epoch: 187 | Train Loss: 0.6979 | Valid Loss: 1.1611 | Train Acc: 0.7604 | Valid Acc: 0.5714
# Epoch: 188 | Train Loss: 0.7322 | Valid Loss: 1.2016 | Train Acc: 0.6788 | Valid Acc: 0.4762
# Epoch: 189 | Train Loss: 0.7577 | Valid Loss: 1.1865 | Train Acc: 0.6198 | Valid Acc: 0.4286
# Epoch: 190 | Train Loss: 0.8101 | Valid Loss: 1.1948 | Train Acc: 0.6736 | Valid Acc: 0.3810
# Epoch: 191 | Train Loss: 0.7497 | Valid Loss: 1.1948 | Train Acc: 0.7135 | Valid Acc: 0.4762
# Epoch: 192 | Train Loss: 0.8193 | Valid Loss: 1.3903 | Train Acc: 0.6337 | Valid Acc: 0.4762
# Epoch: 193 | Train Loss: 0.7486 | Valid Loss: 1.2366 | Train Acc: 0.6615 | Valid Acc: 0.3810
# Epoch: 194 | Train Loss: 0.6540 | Valid Loss: 1.3035 | Train Acc: 0.7674 | Valid Acc: 0.4762
# Epoch: 195 | Train Loss: 0.6580 | Valid Loss: 1.3469 | Train Acc: 0.7222 | Valid Acc: 0.4762
# Epoch: 196 | Train Loss: 0.6829 | Valid Loss: 1.5669 | Train Acc: 0.6858 | Valid Acc: 0.4762
# Epoch: 197 | Train Loss: 0.7383 | Valid Loss: 1.2895 | Train Acc: 0.7378 | Valid Acc: 0.4286
# Epoch: 198 | Train Loss: 0.7317 | Valid Loss: 1.3065 | Train Acc: 0.6701 | Valid Acc: 0.4762
# Epoch: 199 | Train Loss: 0.6897 | Valid Loss: 1.3966 | Train Acc: 0.6944 | Valid Acc: 0.4286
# Epoch: 200 | Train Loss: 0.6751 | Valid Loss: 1.4234 | Train Acc: 0.7240 | Valid Acc: 0.3810
# Best validation accuracy: 0.6667

# %%
plt.plot(range(len(train_losses)), train_losses, label = 'Train loss')
plt.plot(range(len(valid_losses)), valid_losses, label = 'Valid loss')
plt.legend()

# %% [markdown]
# * To Do: lessen number of parameters in version 2 of this network (Which has 1B parameters currently)
